# %%
# %%bash
# which python
# Out:
# /Users/binarycat/work/learning-session-26-11-2025-demo/uv-project/.venv/bin/python

# %%
from requests import get

# %%
get?
# Out:
# Signature: get(url, params=None, **kwargs)
# Docstring:
# Sends a GET request.
#
# :param url: URL for the new :class:`Request` object.
# :param params: (optional) Dictionary, list of tuples or bytes to send
#     in the query string for the :class:`Request`.
# :param \*\*kwargs: Optional arguments that ``request`` takes.
# :return: :class:`Response <Response>` object
# :rtype: requests.Response
# File:      ~/work/learning-session-26-11-2025-demo/uv-project/.venv/lib/python3.11/site-packages/requests/api.py
# Type:      function

# %%
r = get("https://google.com/?q=python")

# %%
r.status_code
# Out:
# 200
